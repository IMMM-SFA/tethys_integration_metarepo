# %% [markdown]
# # IM3 Tethys Outputs Analysis
#
# This notebook analyzes the outputs from IM3 Tethys runs. It includes functions to read output files, summarize data, and plot results.

# %%
import xarray as xr
import os
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

# scenarios = [
#     'rcp45cooler_ssp3', 'rcp45cooler_ssp5',
#     'rcp45hotter_ssp3', 'rcp45hotter_ssp5',
#     'rcp85cooler_ssp3', 'rcp85cooler_ssp5',
#     'rcp85hotter_ssp3', 'rcp85hotter_ssp5',
# ]

# sum for a given sector, type and year
def sector_sum(outputs_dir, scenario, sector, type, year):
    """
    Compute summed values for a given sector, type, and year using sector-specific logic.
    Handles datasets with or without monthly dimensions.
    """
    config = {
        "Electricity": lambda ds: [v for v in ds.data_vars if v.startswith("electricity_")],
        "Irrigation": lambda ds: [v for v in ds.data_vars if v[0].isupper() or v == "biomass"],
        "Domestic": lambda ds: [v for v in ds.data_vars if v.startswith("Domestic")],
        "Livestock": lambda ds: [v for v in ds.data_vars if v[0].isupper()],
        "Manufacturing": lambda ds: [v for v in ds.data_vars if v.startswith("Manufacturing")],
        "Mining": lambda ds: [v for v in ds.data_vars if v.startswith("Mining")],
    }
    if sector not in config:
        raise ValueError(f"Unknown sector: {sector}")
    ds = xr.open_dataset(f"{outputs_dir}/{scenario}/{sector}_{type}.nc")
    selected_vars = config[sector](ds)
    if not selected_vars:
        raise ValueError(f"No valid variables for sector '{sector}' and type '{type}'.")
    
    # sum across 'month' dimension if present, then collapse over lat/lon
    if "month" in ds.dims:
        return sum(ds[v] for v in selected_vars).sum(dim=["lat", "lon", "month"]).sel(year=year)
    else:
        # sum directly across lat/lon for yearly datasets
        return sum(ds[v] for v in selected_vars).sum(dim=["lat", "lon"]).sel(year=year)

# summarize all .nc files/sectors in the scenario folder
def summarize_sectors(outputs_dir, scenario, year):
    """
    Summarize all .nc files in the specified scenario folder into a table.
    Handles both yearly and monthly outputs, collapsing monthly data into yearly results.
    Filters unsupported files like 'gridded_runoff_shares.nc'.
    """
    results = []
    for file_name in os.listdir(f"{outputs_dir}/{scenario}"):
        if file_name.endswith(".nc"):  # process only NetCDF files
            if "gridded_runoff_shares" in file_name:
                continue  # skip unsupported files
            
            try:
                # parse sector and type from the file name
                parts = file_name[:-3].split("_")  # remove ".nc" file extension and split
                if len(parts) >= 2:
                    sector, type = parts[0], parts[1]
                    
                    # Call the sector_sum function
                    sector_sum_result = sector_sum(outputs_dir, scenario, sector, type, year)
                    
                    if sector_sum_result is not None:
                        results.append({
                            "File": file_name,
                            "Sector": sector,
                            "Type": type,
                            "Year": year,
                            "Sum": float(sector_sum_result.values) if sector_sum_result.size == 1 else None,
                        })
            except Exception as e:
                # log error and continue to next file
                results.append({
                    "File": file_name,
                    "Sector": None,
                    "Type": None,
                    "Year": year,
                    "Sum": None,
                    "Error": str(e),
                })
    return pd.DataFrame(results)

# %%
# params
outputs_dir = '../../output_test'
scenario = 'rcp45cooler_ssp3'
sector = 'Electricity'
type = 'withdrawals'
year = 2020

# %%
# take a look at one output
df = xr.open_dataset(f'{outputs_dir}/{scenario}/{sector}_{type}.nc') 
df
# Out:
# <xarray.Dataset> Size: 41MB
# Dimensions:                      (year: 7, lat: 224, lon: 464)
# Coordinates:
#   * lon                          (lon) float64 4kB -124.9 -124.8 ... -67.06
#   * lat                          (lat) float64 2kB 52.94 52.81 ... 25.19 25.06
#     spatial_ref                  int64 8B ...
#   * year                         (year) int64 56B 2020 2025 2030 ... 2045 2050
# Data variables:
#     electricity_biomass          (year, lat, lon) float64 6MB ...
#     electricity_coal             (year, lat, lon) float64 6MB ...
#     electricity_gas              (year, lat, lon) float64 6MB ...
#     electricity_geothermal       (year, lat, lon) float64 6MB ...
#     electricity_nuclear          (year, lat, lon) float64 6MB ...
#     electricity_refined liquids  (year, lat, lon) float64 6MB ...
#     electricity_solar            (year, lat, lon) float64 6MB ...

# %%
electricity_sum = sector_sum(outputs_dir, scenario, sector="Electricity", type=type, year=year)
electricity_sum
# Out:
# <xarray.DataArray ()> Size: 8B
# array(115.62228302)
# Coordinates:
#     spatial_ref  int64 8B 0
#     year         int64 8B 2020

# %% [markdown]
# 2020 comparisons

# %%
summary_table = summarize_sectors(outputs_dir, scenario, year).sort_values(by=["Sector", "Type"])
summary_table
# Out:
#                                     File         Sector         Type  Year  \
# 12               Domestic_consumption.nc       Domestic  consumption  2020
# 13       Domestic_consumption_monthly.nc       Domestic  consumption  2020
# 0                Domestic_withdrawals.nc       Domestic  withdrawals  2020
# 1        Domestic_withdrawals_monthly.nc       Domestic  withdrawals  2020
# 14            Electricity_consumption.nc    Electricity  consumption  2020
# 15    Electricity_consumption_monthly.nc    Electricity  consumption  2020
# 2             Electricity_withdrawals.nc    Electricity  withdrawals  2020
# 3     Electricity_withdrawals_monthly.nc    Electricity  withdrawals  2020
# 16             Irrigation_consumption.nc     Irrigation  consumption  2020
# 17     Irrigation_consumption_monthly.nc     Irrigation  consumption  2020
# 4              Irrigation_withdrawals.nc     Irrigation  withdrawals  2020
# 5      Irrigation_withdrawals_monthly.nc     Irrigation  withdrawals  2020
# 18              Livestock_consumption.nc      Livestock  consumption  2020
# 19      Livestock_consumption_monthly.nc      Livestock  consumption  2020
# 6               Livestock_withdrawals.nc      Livestock  withdrawals  2020
# 7       Livestock_withdrawals_monthly.nc      Livestock  withdrawals  2020
# 20          Manufacturing_consumption.nc  Manufacturing  consumption  2020
# 21  Manufacturing_consumption_monthly.nc  Manufacturing  consumption  2020
# 8           Manufacturing_withdrawals.nc  Manufacturing  withdrawals  2020
# 9   Manufacturing_withdrawals_monthly.nc  Manufacturing  withdrawals  2020
# 22                 Mining_consumption.nc         Mining  consumption  2020
# 23         Mining_consumption_monthly.nc         Mining  consumption  2020
# 10                 Mining_withdrawals.nc         Mining  withdrawals  2020
# 11         Mining_withdrawals_monthly.nc         Mining  withdrawals  2020
#
#            Sum
# 12    9.336301
# 13    9.336301
# 0    59.153167
# 1    59.153167
# 14    4.403557
# 15    4.403557
# 2   115.622283
# 3   115.622283
# 16   79.391847
# 17   79.391847
# 4   122.901837
# 5   122.901837
# 18    2.781864
# 19    2.781864
# 6     2.781864
# 7     2.781864
# 20    4.748621
# 21    4.748621
# 8    20.056824
# 9    20.056824
# 22    1.409973
# 23    1.409973
# 10    4.622860
# 11    4.622860

# %%
summary_table = summarize_sectors(outputs_dir = '../../output_supersector', scenario=scenario, year=2020).sort_values(by=["Sector", "Type"])
summary_table
# Out:
#                                     File         Sector         Type  Year  \
# 12               Domestic_consumption.nc       Domestic  consumption  2020
# 13       Domestic_consumption_monthly.nc       Domestic  consumption  2020
# 0                Domestic_withdrawals.nc       Domestic  withdrawals  2020
# 1        Domestic_withdrawals_monthly.nc       Domestic  withdrawals  2020
# 14            Electricity_consumption.nc    Electricity  consumption  2020
# 15    Electricity_consumption_monthly.nc    Electricity  consumption  2020
# 2             Electricity_withdrawals.nc    Electricity  withdrawals  2020
# 3     Electricity_withdrawals_monthly.nc    Electricity  withdrawals  2020
# 16             Irrigation_consumption.nc     Irrigation  consumption  2020
# 17     Irrigation_consumption_monthly.nc     Irrigation  consumption  2020
# 4              Irrigation_withdrawals.nc     Irrigation  withdrawals  2020
# 5      Irrigation_withdrawals_monthly.nc     Irrigation  withdrawals  2020
# 18              Livestock_consumption.nc      Livestock  consumption  2020
# 19      Livestock_consumption_monthly.nc      Livestock  consumption  2020
# 6               Livestock_withdrawals.nc      Livestock  withdrawals  2020
# 7       Livestock_withdrawals_monthly.nc      Livestock  withdrawals  2020
# 20          Manufacturing_consumption.nc  Manufacturing  consumption  2020
# 21  Manufacturing_consumption_monthly.nc  Manufacturing  consumption  2020
# 8           Manufacturing_withdrawals.nc  Manufacturing  withdrawals  2020
# 9   Manufacturing_withdrawals_monthly.nc  Manufacturing  withdrawals  2020
# 22                 Mining_consumption.nc         Mining  consumption  2020
# 23         Mining_consumption_monthly.nc         Mining  consumption  2020
# 10                 Mining_withdrawals.nc         Mining  withdrawals  2020
# 11         Mining_withdrawals_monthly.nc         Mining  withdrawals  2020
#
#            Sum
# 12    9.336301
# 13    9.336301
# 0    59.153167
# 1    59.153167
# 14    4.403557
# 15    4.403557
# 2   115.622283
# 3   115.622283
# 16   79.379992
# 17   79.379992
# 4   122.883484
# 5   122.883484
# 18    2.781864
# 19    2.781864
# 6     2.781864
# 7     2.781864
# 20    4.748621
# 21    4.748621
# 8    20.056824
# 9    20.056824
# 22    1.409973
# 23    1.409973
# 10    4.622860
# 11    4.622860

# %%
summarize_sectors(outputs_dir = '../../output_sunflowerfix', scenario=scenario, year=2020).sort_values(by=["Sector", "Type"])
# Out:
#                                     File         Sector         Type  Year  \
# 12               Domestic_consumption.nc       Domestic  consumption  2020
# 13       Domestic_consumption_monthly.nc       Domestic  consumption  2020
# 0                Domestic_withdrawals.nc       Domestic  withdrawals  2020
# 1        Domestic_withdrawals_monthly.nc       Domestic  withdrawals  2020
# 14            Electricity_consumption.nc    Electricity  consumption  2020
# 15    Electricity_consumption_monthly.nc    Electricity  consumption  2020
# 2             Electricity_withdrawals.nc    Electricity  withdrawals  2020
# 3     Electricity_withdrawals_monthly.nc    Electricity  withdrawals  2020
# 16             Irrigation_consumption.nc     Irrigation  consumption  2020
# 17     Irrigation_consumption_monthly.nc     Irrigation  consumption  2020
# 4              Irrigation_withdrawals.nc     Irrigation  withdrawals  2020
# 5      Irrigation_withdrawals_monthly.nc     Irrigation  withdrawals  2020
# 18              Livestock_consumption.nc      Livestock  consumption  2020
# 19      Livestock_consumption_monthly.nc      Livestock  consumption  2020
# 6               Livestock_withdrawals.nc      Livestock  withdrawals  2020
# 7       Livestock_withdrawals_monthly.nc      Livestock  withdrawals  2020
# 20          Manufacturing_consumption.nc  Manufacturing  consumption  2020
# 21  Manufacturing_consumption_monthly.nc  Manufacturing  consumption  2020
# 8           Manufacturing_withdrawals.nc  Manufacturing  withdrawals  2020
# 9   Manufacturing_withdrawals_monthly.nc  Manufacturing  withdrawals  2020
# 22                 Mining_consumption.nc         Mining  consumption  2020
# 23         Mining_consumption_monthly.nc         Mining  consumption  2020
# 10                 Mining_withdrawals.nc         Mining  withdrawals  2020
# 11         Mining_withdrawals_monthly.nc         Mining  withdrawals  2020
#
#            Sum
# 12    9.336301
# 13    9.336301
# 0    59.153167
# 1    59.153167
# 14    4.403557
# 15    4.403557
# 2   115.622283
# 3   115.622283
# 16   79.379992
# 17   79.379992
# 4   122.883484
# 5   122.883484
# 18    2.781864
# 19    2.781864
# 6     2.781864
# 7     2.781864
# 20    4.748621
# 21    4.748621
# 8    20.056824
# 9    20.056824
# 22    1.409973
# 23    1.409973
# 10    4.622860
# 11    4.622860

# %% [markdown]
# 2050 comparison

# %%
summary_table = summarize_sectors(outputs_dir = '../../output_test', scenario=scenario, year=2050).sort_values(by=["Sector", "Type"])
summary_table
# Out:
#                                     File         Sector         Type  Year  \
# 12               Domestic_consumption.nc       Domestic  consumption  2050
# 13       Domestic_consumption_monthly.nc       Domestic  consumption  2050
# 0                Domestic_withdrawals.nc       Domestic  withdrawals  2050
# 1        Domestic_withdrawals_monthly.nc       Domestic  withdrawals  2050
# 14            Electricity_consumption.nc    Electricity  consumption  2050
# 15    Electricity_consumption_monthly.nc    Electricity  consumption  2050
# 2             Electricity_withdrawals.nc    Electricity  withdrawals  2050
# 3     Electricity_withdrawals_monthly.nc    Electricity  withdrawals  2050
# 16             Irrigation_consumption.nc     Irrigation  consumption  2050
# 17     Irrigation_consumption_monthly.nc     Irrigation  consumption  2050
# 4              Irrigation_withdrawals.nc     Irrigation  withdrawals  2050
# 5      Irrigation_withdrawals_monthly.nc     Irrigation  withdrawals  2050
# 18              Livestock_consumption.nc      Livestock  consumption  2050
# 19      Livestock_consumption_monthly.nc      Livestock  consumption  2050
# 6               Livestock_withdrawals.nc      Livestock  withdrawals  2050
# 7       Livestock_withdrawals_monthly.nc      Livestock  withdrawals  2050
# 20          Manufacturing_consumption.nc  Manufacturing  consumption  2050
# 21  Manufacturing_consumption_monthly.nc  Manufacturing  consumption  2050
# 8           Manufacturing_withdrawals.nc  Manufacturing  withdrawals  2050
# 9   Manufacturing_withdrawals_monthly.nc  Manufacturing  withdrawals  2050
# 22                 Mining_consumption.nc         Mining  consumption  2050
# 23         Mining_consumption_monthly.nc         Mining  consumption  2050
# 10                 Mining_withdrawals.nc         Mining  withdrawals  2050
# 11         Mining_withdrawals_monthly.nc         Mining  withdrawals  2050
#
#            Sum
# 12    9.173410
# 13    9.173410
# 0    56.833293
# 1    56.833293
# 14    1.245051
# 15    1.245051
# 2     6.602648
# 3     6.602648
# 16   96.133443
# 17   96.133443
# 4   148.818458
# 5   148.818458
# 18    3.217013
# 19    3.217013
# 6     3.217013
# 7     3.217013
# 20    5.147866
# 21    5.147866
# 8    20.861138
# 9    20.861138
# 22    0.971202
# 23    0.971202
# 10    3.184259
# 11    3.184259

# %%
summary_table = summarize_sectors(outputs_dir = '../../output_supersector', scenario=scenario, year=2050).sort_values(by=["Sector", "Type"])
summary_table
# Out:
#                                     File         Sector         Type  Year  \
# 12               Domestic_consumption.nc       Domestic  consumption  2050
# 13       Domestic_consumption_monthly.nc       Domestic  consumption  2050
# 0                Domestic_withdrawals.nc       Domestic  withdrawals  2050
# 1        Domestic_withdrawals_monthly.nc       Domestic  withdrawals  2050
# 14            Electricity_consumption.nc    Electricity  consumption  2050
# 15    Electricity_consumption_monthly.nc    Electricity  consumption  2050
# 2             Electricity_withdrawals.nc    Electricity  withdrawals  2050
# 3     Electricity_withdrawals_monthly.nc    Electricity  withdrawals  2050
# 16             Irrigation_consumption.nc     Irrigation  consumption  2050
# 17     Irrigation_consumption_monthly.nc     Irrigation  consumption  2050
# 4              Irrigation_withdrawals.nc     Irrigation  withdrawals  2050
# 5      Irrigation_withdrawals_monthly.nc     Irrigation  withdrawals  2050
# 18              Livestock_consumption.nc      Livestock  consumption  2050
# 19      Livestock_consumption_monthly.nc      Livestock  consumption  2050
# 6               Livestock_withdrawals.nc      Livestock  withdrawals  2050
# 7       Livestock_withdrawals_monthly.nc      Livestock  withdrawals  2050
# 20          Manufacturing_consumption.nc  Manufacturing  consumption  2050
# 21  Manufacturing_consumption_monthly.nc  Manufacturing  consumption  2050
# 8           Manufacturing_withdrawals.nc  Manufacturing  withdrawals  2050
# 9   Manufacturing_withdrawals_monthly.nc  Manufacturing  withdrawals  2050
# 22                 Mining_consumption.nc         Mining  consumption  2050
# 23         Mining_consumption_monthly.nc         Mining  consumption  2050
# 10                 Mining_withdrawals.nc         Mining  withdrawals  2050
# 11         Mining_withdrawals_monthly.nc         Mining  withdrawals  2050
#
#            Sum
# 12    9.173410
# 13    9.173410
# 0    56.833293
# 1    56.833293
# 14    1.245051
# 15    1.245051
# 2     6.602648
# 3     6.602648
# 16   96.133443
# 17   96.133443
# 4   148.818458
# 5   148.818458
# 18    3.217013
# 19    3.217013
# 6     3.217013
# 7     3.217013
# 20    5.147866
# 21    5.147866
# 8    20.861138
# 9    20.861138
# 22    0.971202
# 23    0.971202
# 10    3.184259
# 11    3.184259

# %%
summarize_sectors(outputs_dir = '../../output_sunflowerfix', scenario=scenario, year=2050).sort_values(by=["Sector", "Type"])
# Out:
#                                     File         Sector         Type  Year  \
# 12               Domestic_consumption.nc       Domestic  consumption  2050
# 13       Domestic_consumption_monthly.nc       Domestic  consumption  2050
# 0                Domestic_withdrawals.nc       Domestic  withdrawals  2050
# 1        Domestic_withdrawals_monthly.nc       Domestic  withdrawals  2050
# 14            Electricity_consumption.nc    Electricity  consumption  2050
# 15    Electricity_consumption_monthly.nc    Electricity  consumption  2050
# 2             Electricity_withdrawals.nc    Electricity  withdrawals  2050
# 3     Electricity_withdrawals_monthly.nc    Electricity  withdrawals  2050
# 16             Irrigation_consumption.nc     Irrigation  consumption  2050
# 17     Irrigation_consumption_monthly.nc     Irrigation  consumption  2050
# 4              Irrigation_withdrawals.nc     Irrigation  withdrawals  2050
# 5      Irrigation_withdrawals_monthly.nc     Irrigation  withdrawals  2050
# 18              Livestock_consumption.nc      Livestock  consumption  2050
# 19      Livestock_consumption_monthly.nc      Livestock  consumption  2050
# 6               Livestock_withdrawals.nc      Livestock  withdrawals  2050
# 7       Livestock_withdrawals_monthly.nc      Livestock  withdrawals  2050
# 20          Manufacturing_consumption.nc  Manufacturing  consumption  2050
# 21  Manufacturing_consumption_monthly.nc  Manufacturing  consumption  2050
# 8           Manufacturing_withdrawals.nc  Manufacturing  withdrawals  2050
# 9   Manufacturing_withdrawals_monthly.nc  Manufacturing  withdrawals  2050
# 22                 Mining_consumption.nc         Mining  consumption  2050
# 23         Mining_consumption_monthly.nc         Mining  consumption  2050
# 10                 Mining_withdrawals.nc         Mining  withdrawals  2050
# 11         Mining_withdrawals_monthly.nc         Mining  withdrawals  2050
#
#            Sum
# 12    9.173410
# 13    9.173410
# 0    56.833293
# 1    56.833293
# 14    1.245051
# 15    1.245051
# 2     6.602648
# 3     6.602648
# 16   96.133443
# 17   96.133443
# 4   148.818458
# 5   148.818458
# 18    3.217013
# 19    3.217013
# 6     3.217013
# 7     3.217013
# 20    5.147866
# 21    5.147866
# 8    20.861138
# 9    20.861138
# 22    0.971202
# 23    0.971202
# 10    3.184259
# 11    3.184259

# %%
# elec lumped 
summarize_sectors(outputs_dir = '../../output_test', scenario=scenario, year=2050).sort_values(by=["Sector", "Type"])
# Out:
#                                     File         Sector         Type  Year  \
# 12               Domestic_consumption.nc       Domestic  consumption  2050
# 13       Domestic_consumption_monthly.nc       Domestic  consumption  2050
# 0                Domestic_withdrawals.nc       Domestic  withdrawals  2050
# 1        Domestic_withdrawals_monthly.nc       Domestic  withdrawals  2050
# 14            Electricity_consumption.nc    Electricity  consumption  2050
# 15    Electricity_consumption_monthly.nc    Electricity  consumption  2050
# 2             Electricity_withdrawals.nc    Electricity  withdrawals  2050
# 3     Electricity_withdrawals_monthly.nc    Electricity  withdrawals  2050
# 16             Irrigation_consumption.nc     Irrigation  consumption  2050
# 17     Irrigation_consumption_monthly.nc     Irrigation  consumption  2050
# 4              Irrigation_withdrawals.nc     Irrigation  withdrawals  2050
# 5      Irrigation_withdrawals_monthly.nc     Irrigation  withdrawals  2050
# 18              Livestock_consumption.nc      Livestock  consumption  2050
# 19      Livestock_consumption_monthly.nc      Livestock  consumption  2050
# 6               Livestock_withdrawals.nc      Livestock  withdrawals  2050
# 7       Livestock_withdrawals_monthly.nc      Livestock  withdrawals  2050
# 20          Manufacturing_consumption.nc  Manufacturing  consumption  2050
# 21  Manufacturing_consumption_monthly.nc  Manufacturing  consumption  2050
# 8           Manufacturing_withdrawals.nc  Manufacturing  withdrawals  2050
# 9   Manufacturing_withdrawals_monthly.nc  Manufacturing  withdrawals  2050
# 22                 Mining_consumption.nc         Mining  consumption  2050
# 23         Mining_consumption_monthly.nc         Mining  consumption  2050
# 10                 Mining_withdrawals.nc         Mining  withdrawals  2050
# 11         Mining_withdrawals_monthly.nc         Mining  withdrawals  2050
#
#            Sum
# 12    9.173410
# 13    9.173410
# 0    56.833293
# 1    56.833293
# 14    1.245051
# 15    1.245051
# 2     6.602648
# 3     6.602648
# 16  103.723652
# 17  103.723652
# 4   160.568403
# 5   160.568403
# 18    3.217013
# 19    3.217013
# 6     3.217013
# 7     3.217013
# 20    5.147866
# 21    5.147866
# 8    20.861138
# 9    20.861138
# 22    0.971202
# 23    0.971202
# 10    3.184259
# 11    3.184259

# %%
summarize_sectors(outputs_dir = '../../output_test', scenario=scenario, year=2050).sort_values(by=["Sector", "Type"])
